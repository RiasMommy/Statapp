# %%
import pandas as pd

# Adapter le chemin si besoin
file_path = "/home/onyxia/Statapp/data/rawdata.csv"

df = pd.read_csv(file_path)

# Vérification rapide
df.shape
# Out:
# (10015, 44)

# %%
# 1) Premier aperçu des lignes
df.head()  # premières lignes

# 2) Un échantillon aléatoire
df.sample(5, random_state=0)

# 3) Informations générales (types, valeurs manquantes, etc.)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 44 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   league                                              10015 non-null  object
#  1   season                                              7172 non-null   float64
#  2   team                                                7172 non-null   object
#  3   player                                              7172 non-null   object
#  4   nation                                              7172 non-null   object
#  5   pos                                                 7172 non-null   object
#  6   age                                                 7172 non-null   float64
#  7   born                                                7172 non-null   float64
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# xG / Tir                                              4367
# % dribble  rÃ©ussis                                   4157
# % duels aÃ©riens gagnÃ©s                              3452
# % passes longues rÃ©ussies                            3256
# DÃ©gagements                                          2973
# Erreurs menant Ã  un tir adverse                      2973
# Tirs                                                  2973
# Tirs cadrÃ©s                                          2973
# Dribbles subis perdus                                 2973
# Blocs totaux                                          2973
# Interceptions                                         2973
# Tacles rÃ©ussis + interceptions                       2973
# Distance totale des passes > 10m avant effectuÃ©es    2973
# Passes menant Ã  un but                               2973
# Touches ballon en jeu                                 2973
# Passes reÃ§ues                                        2973
# ...

# %%
df[df["player"].isna()].head(60)
# Out:
#                                                 league  season team player  \
# 4    ITA-Serie A,2020,Bologna,Andreas Skov Olsen,DE...     NaN  NaN    NaN
# 7    ITA-Serie A,2020,Benevento,AndrÃ©s Tello,COL,"...     NaN  NaN    NaN
# 8    ITA-Serie A,2020,Juventus,Alessandro Di Pardo,...     NaN  NaN    NaN
# 14   ITA-Serie A,2020,Parma,Alberto Grassi,ITA,"MF,...     NaN  NaN    NaN
# 16   ITA-Serie A,2020,Fiorentina,Aleksandr Kokorin,...     NaN  NaN    NaN
# 30   ITA-Serie A,2020,Milan,Brahim DÃ­az,MAR,"MF,FW...     NaN  NaN    NaN
# 32   ITA-Serie A,2020,Sassuolo,Brian Oddei,ITA,"FW,...     NaN  NaN    NaN
# 44   ITA-Serie A,2020,Lazio,Andreas Pereira,BRA,"FW...     NaN  NaN    NaN
# 58   ITA-Serie A,2020,Hellas Verona,Ronaldo Vieira,...     NaN  NaN    NaN
# 59   ITA-Serie A,2020,Hellas Verona,Ronaldo Vieira,...     NaN  NaN    NaN
# 60   ITA-Serie A,2020,Atalanta,Ruslan Malinovskyi,U...     NaN  NaN    NaN
# ...

# %%
df["league"].str.split(",", expand=True).head(30)
# Out:
#              0     1           2                    3     4     5     6   \
# 0   ITA-Serie A  None        None                 None  None  None  None
# 1   ITA-Serie A  None        None                 None  None  None  None
# 2   ITA-Serie A  None        None                 None  None  None  None
# 3   ITA-Serie A  None        None                 None  None  None  None
# 4   ITA-Serie A  2020     Bologna   Andreas Skov Olsen   DEN   "FW   DF"
# 5   ITA-Serie A  None        None                 None  None  None  None
# 6   ITA-Serie A  None        None                 None  None  None  None
# 7   ITA-Serie A  2020   Benevento        AndrÃ©s Tello   COL   "DF   MF"
# 8   ITA-Serie A  2020    Juventus  Alessandro Di Pardo   ITA   "FW   DF"
# 9   ITA-Serie A  None        None                 None  None  None  None
# 10  ITA-Serie A  None        None                 None  None  None  None
# 11  ITA-Serie A  None        None                 None  None  None  None
# ...

# %%
split = df["league"].str.split(",", expand=True)

split.head(15)
# Out:
#              0     1          2                    3     4     5     6     7   \
# 0   ITA-Serie A  None       None                 None  None  None  None  None
# 1   ITA-Serie A  None       None                 None  None  None  None  None
# 2   ITA-Serie A  None       None                 None  None  None  None  None
# 3   ITA-Serie A  None       None                 None  None  None  None  None
# 4   ITA-Serie A  2020    Bologna   Andreas Skov Olsen   DEN   "FW   DF"  20.0
# 5   ITA-Serie A  None       None                 None  None  None  None  None
# 6   ITA-Serie A  None       None                 None  None  None  None  None
# 7   ITA-Serie A  2020  Benevento        AndrÃ©s Tello   COL   "DF   MF"  23.0
# 8   ITA-Serie A  2020   Juventus  Alessandro Di Pardo   ITA   "FW   DF"  21.0
# 9   ITA-Serie A  None       None                 None  None  None  None  None
# 10  ITA-Serie A  None       None                 None  None  None  None  None
# ...

# %%
split.isna().sum()
# Out:
# 0        0
# 1     7172
# 2     7172
# 3     7172
# 4     7172
# 5     7172
# 6     7172
# 7     7172
# 8     7172
# 9     7172
# 10    7172
# 11    7172
# 12    7172
# 13    7172
# 14    7172
# 15    7172
# 16    7172
# 17    7172
# 18    7172
# 19    7172
# 20    7172
# 21    7172
# 22    7172
# 23    7172
# 24    7172
# 25    7172
# 26    7172
# 27    7172
# 28    7172
# 29    7172
# 30    7172
# 31    7172
# 32    7172
# 33    7172
# 34    7172
# 35    7172
# 36    7172
# 37    7172
# 38    7172
# 39    7172
# 40    7172
# 41    7172
# 42    7172
# 43    7172
# 44    7172
# dtype: int64

# %%
import pandas as pd

df_clean = pd.read_csv("../data/processed/players_clean.csv")

# %%
df["season"]
# Out:
# 0        2020.0
# 1        2020.0
# 2        2020.0
# 3        2020.0
# 4           NaN
#           ...
# 10010       NaN
# 10011       NaN
# 10012    2023.0
# 10013       NaN
# 10014       NaN
# Name: season, Length: 10015, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 44 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   league                                              10015 non-null  object
#  1   season                                              7172 non-null   float64
#  2   team                                                7172 non-null   object
#  3   player                                              7172 non-null   object
#  4   nation                                              7172 non-null   object
#  5   pos                                                 7172 non-null   object
#  6   age                                                 7172 non-null   float64
#  7   born                                                7172 non-null   float64
# ...

# %%
df["pos"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='pos'>

# %%
df[["minutes", "age", "xg", "xag"]].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[["minutes", "age", "xg", "xag"]].describe()
#
# File /opt/python/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/python/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df["xg_per90"].hist(bins=20)
df["minutes"].hist(bins=30)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(data=df[["xg", "xag", "npxg"]])
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 44 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   league                                              10015 non-null  object
#  1   season                                              7172 non-null   float64
#  2   team                                                7172 non-null   object
#  3   player                                              7172 non-null   object
#  4   nation                                              7172 non-null   object
#  5   pos                                                 7172 non-null   object
#  6   age                                                 7172 non-null   float64
#  7   born                                                7172 non-null   float64
# ...

# %%
df_clean.isna().sum().sort_values()
# Out:
# league                     0
# season                     0
# team                       0
# player                     0
# nation                     0
# age                        0
# born_year                  0
# minutes                    0
# gls                        0
# ast                        0
# g_plus_a                   0
# g_minus_pk                 0
# pk                         0
# pk_att                     0
# crdy                       0
# crdr                       0
# xg                         0
# npxg                       0
# xag                        0
# prgc                       0
# prgr                       0
# prgp                       0
# pos                        0
# xg_per90                  14
# npxg_plus_xag_per90       14
# touches                   14
# npxg_per90                14
# xg_plus_xag_per90         14
# interceptions             14
# blocks                    14
# tackles_won               14
# xag_per90                 14
# ...
